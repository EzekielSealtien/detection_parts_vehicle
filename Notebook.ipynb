# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install roboflow ultralytics 'git+https://github.com/facebookresearch/segment-anything.git'
# Out:
# ...
#   Cloning https://github.com/facebookresearch/segment-anything.git to /tmp/pip-req-build-jyyv57c6
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/segment-anything.git /tmp/pip-req-build-jyyv57c6
#   Resolved https://github.com/facebookresearch/segment-anything.git to commit dca509fe793f601edb92606367a655c15ac00fdf
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 kB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 17.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 976.9/976.9 kB 49.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 88.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 82.6 MB/s eta 0:00:00
# ...

# %%
# %cd /content/drive/MyDrive/My_Project.v1i.yolov8
# Out:
# /content/drive/MyDrive/My_Project.v1i.yolov8

# %%
# !ls
# Out:
# best.pt    README.dataset.txt	result1.jpg  test   valid
# data.yaml  README.roboflow.txt	runs	     train  yolov8n.pt

# %%
ROOT_DIR  = '/content/drive/MyDrive/My_Project.v1i.yolov8'

# %%
import os

from ultralytics import YOLO


# Load a model
model = YOLO('yolov8n.pt')

# Use the model
results = model.train(data=os.path.join(ROOT_DIR, "data.yaml"), epochs=10)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.99 🚀 Python-3.11.11 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# ...

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
# Validate the model
metrics = model.val(data = "data.yaml")
# Out:
# Ultralytics 8.3.99 🚀 Python-3.11.11 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 72 layers, 3,006,818 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/My_Project.v1i.yolov8/valid/labels.cache... 43 images, 0 backgrounds, 0 corrupt: 100%|██████████| 43/43 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:13<00:00,  4.41s/it]
#                    all         43        347       0.88      0.793      0.892      0.506
#                  capot         35         36      0.854      0.806      0.884      0.498
#             pare-brise         43         44      0.773      0.864      0.905      0.557
#                  phare         43         76      0.925      0.566      0.776      0.424
#               portiere         38         62      0.845      0.839      0.923      0.525
# ...

# %%
# !scp -r runs/detect/train52 /content/drive/MyDrive
# Out:
# cp: cannot stat 'runs/detect/train52/weights/best.pt': No such file or directory

# %%
model = YOLO("runs/detect/train/weights/best.pt")  # pretrained YOLOv8n model

# Run batched inference on a list of images

# %%
path2='/content/drive/MyDrive/make_an_inference/01031.jpg'
results = model(path2, save=True, line_width=1)
# Process results list
for result in results:
    boxes = result.boxes
    result.save(filename="result1.jpg")
# Out:
# image 1/1 /content/drive/MyDrive/make_an_inference/01031.jpg: 384x640 2 capots, 1 pare-brise, 4 phares, 2 portieres, 1 retroviseur, 3 roues, 147.6ms
# Speed: 3.3ms preprocess, 147.6ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict3

# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(10, 10))
img = Image.open("runs/detect/predict/01031.jpg")
image = np.array(img)
plt.imshow(image)
plt.axis('off')
plt.show()

# %%
import shutil
shutil.copy("runs/detect/train5/weights/best.pt", "/content/drive/MyDrive/best.pt")
# Out:
# '/content/drive/MyDrive/best.pt'

# %%
import glob

for path in glob.glob("runs/detect/train*/weights/best.pt"):
    print(path)
# Out:
# runs/detect/train/weights/best.pt
# runs/detect/train2/weights/best.pt
# runs/detect/train3/weights/best.pt
# runs/detect/train4/weights/best.pt
# runs/detect/train5/weights/best.pt
